# %%
import preprocessing
import numpy as np

# %%
data = preprocessing.get_dataset()
# Out:
# Loading data sets
# Empty file, skipping...
# Empty file, skipping...
# Empty file, skipping...
# Empty file, skipping...
# Empty file, skipping...
# Empty file, skipping...
# Empty file, skipping...
# Empty file, skipping...
# Data incomplete, skipping...
# Empty file, skipping...
# Empty file, skipping...
# Empty file, skipping...
# Empty file, skipping...
# Empty file, skipping...
# Empty file, skipping...
# Empty file, skipping...
# Empty file, skipping...
# Empty file, skipping...
# Empty file, skipping...
# Empty file, skipping...
# Empty file, skipping...
# Empty file, skipping...
# Empty file, skipping...
# Empty file, skipping...
# Empty file, skipping...
# Empty file, skipping...
# Empty file, skipping...
# Empty file, skipping...
# Empty file, skipping...
# Empty file, skipping...
# Empty file, skipping...
# Empty file, skipping...
# Empty file, skipping...
# Empty file, skipping...
# Empty file, skipping...
# Empty file, skipping...
# Empty file, skipping...
# ...

# %%
data['x_train'].shape
# Out:
# (45000, 6)
